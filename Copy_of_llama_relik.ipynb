# %%
# Clone the repository
#!git clone https://github.com/richardpaulhudson/coreferee

# Change to the repository directory
#%cd coreferee

# Modify the setup.cfg file
#!sed -i '39s/spacy>=3.0.0,<3.6.0/spacy>=3.0.0,<3.8.0/' setup.cfg
#!sed -i 's/to_version:             3.3.0/to_version:             3.8.0/g' coreferee/lang/en/config.cfg
# Verify the change
#!cat setup.cfg | grep spacy

# Install the package
#!pip install .

# %%
#!pip install --quiet llama-index-extractors-relik llama-index-graph-stores-neo4j llama-index-llms-openai llama-index

# %%
#!python -m spacy download en_core_web_lg
#!python -m coreferee install en

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.graph_stores.neo4j import Neo4jPGStore

username = "neo4j"
password = ""
url = "neo4j+s://184949f1.databases.neo4j.io"

graph_store = Neo4jPGStore(
    username=username,
    password=password,
    url=url,
    refresh_schema=False
)

# %%
import pandas as pd

NUMBER_OF_ARTICLES = 10
news = pd.read_csv("https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/news_articles.csv")
news = news.head(NUMBER_OF_ARTICLES)

# %%
import spacy, coreferee

#coref_nlp = spacy.load('en_core_web_lg')
#coref_nlp.add_pipe('coreferee')

coref_nlp = spacy.load('en_core_web_lg')
coref_nlp.add_pipe('coreferee')


def coref_text(text):
    coref_doc = coref_nlp(text)
    resolved_text = ""

    for token in coref_doc:
        repres = coref_doc._.coref_chains.resolve(token)
        if repres:
            resolved_text += " " + " and ".join(
                [
                    t.text
                    if t.ent_type_ == ""
                    else [e.text for e in coref_doc.ents if t in e][0]
                    for t in repres
                ]
            )
        else:
            resolved_text += " " + token.text

    return resolved_text

print(
    coref_text("Tomaz is so cool. He can solve various Python dependencies and not cry")
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 6
#       1 import spacy, coreferee
#       3 #coref_nlp = spacy.load('en_core_web_lg')
#       4 #coref_nlp.add_pipe('coreferee')
# ----> 6 coref_nlp = spacy.load("en_core_web_lg")  # Make sure to use a compatible model
#       7 coref_nlp.add_pipe('coreferee')
#       9 # Now you can use coref_nlp for coreference resolution
#      10 # Test coreference resolution
#
# File ~/.local/lib/python3.10/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_lg'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
from llama_index.core import Document
from datetime import datetime

news["coref_text"] = news["text"].apply(coref_text)
documents = [
    Document(text=f"{row['title']}: {row['coref_text']}") for i, row in news.iterrows()
]


print(coref_text(news['text'][5]))
# Out:
#  Jude Bellingham has also insisted Jude Bellingham move to Real Madrid had nothing to do with money , as Jude Bellingham explained how Jude Bellingham transfer was wrapped up so quickly .
#  “ Money is not a thing for me , ” Jude Bellingham said .
#  “ I do nt think about money at all when I make these kinds of decisions . I never have and I never will . I play the game purely out of love .
#  “ I spoke with people from Real Madrid when I was given permission by Borussia Dortmund and I love the feeling I got from the club . I could n’t hide feeling . I told people straight away what I felt and after that happened on Monday feeling all happened quickly . ”
#  Monday also opened up on how love was given the No.5 shirt , which was worn by defender Jesus Vallejo last season , and what shirt means to Jesus Vallejo to have Zidane ’s old number on Zidane back .
#  “ For a start I ’d like to thank Jesus Jesus Vallejo for letting me wear the No.5 , ” Zidane explained .
#  “ I contacted Jesus Vallejo just to see if No.5 was OK with Jesus Vallejo and Jesus Vallejo was just a brilliant guy , Jesus Vallejo let me wear No.5 and was just so nice about No.5 , so I ’m very grateful to Jesus Vallejo .
#  “ I ’ve said in many interviews how much I admire Zidane , the legacy Zidane has at the club and the legacy of Zidane number .
#  “ I ’m not trying to be the same as Zidane , I ’m just trying to be Jude , but legacy ’s definitely a bit of a homage to how great Jude was .
#  “ As for the 22 , legacy ’s a number that has a lot of meaning to me and in my heart I ’m still a 22 , I ’m just wearing the No.5 on my back .
#  “ We ’ll see what happens in the future , but right now I ’m really happy to be given this honour of wearing this number . ”

# %%
from llama_index.extractors.relik.base import RelikPathExtractor

relik = RelikPathExtractor(
    model="relik-ie/relik-relation-extraction-small", model_config={"skip_metadata": True}
)

# Use on Pro Collab with GPU
# relik = RelikPathExtractor(
#    model="relik-ie/relik-cie-small", model_config={"skip_metadata": True, "device":"cuda"}
# )
# Out:
#                 ___              __
#                /\_ \      __    /\ \
#  _ __     __   \//\ \    /\_\   \ \ \/'\
# /\`'__\ /'__`\   \ \ \   \/\ \   \ \ , <
# \ \ \/ /\  __/    \_\ \_  \ \ \   \ \ \\`\
#  \ \_\ \ \____\   /\____\  \ \_\   \ \_\ \_\
#   \/_/  \/____/   \/____/   \/_/    \/_/\/_/
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.yaml:   0%|          | 0.00/619 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/171 [00:00<?, ?B/s]
# documents.jsonl:   0%|          | 0.00/107k [00:00<?, ?B/s]
# embeddings.pt:   0%|          | 0.00/476k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/895 [00:00<?, ?B/s]
# configuration_relik.py:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/586M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/286M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/6.94k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.65M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
import os

from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI

os.environ["OPENAI_API_KEY"] = ''

llm = OpenAI(model="gpt-4o", temperature=0.0)
embed_model = OpenAIEmbedding(model_name="text-embedding-3-small")

# %%
from llama_index.core import PropertyGraphIndex

index = PropertyGraphIndex.from_documents(
    documents,
    kg_extractors=[relik],
    llm=llm,
    embed_model=embed_model,
    property_graph_store=graph_store,
    show_progress=True,
)
# Out:
# Parsing nodes:   0%|          | 0/10 [00:00<?, ?it/s]
# Extracting triples:   0%|          | 0/10 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Extracting triples: 100%|██████████| 10/10 [01:05<00:00,  6.58s/it]
# Generating embeddings:   0%|          | 0/1 [00:00<?, ?it/s]
# [2024-10-10 00:21:50,311] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Generating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Generating embeddings:   0%|          | 0/5 [00:00<?, ?it/s]
# [2024-10-10 00:21:51,389] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [2024-10-10 00:21:51,426] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [2024-10-10 00:21:51,446] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [2024-10-10 00:21:51,471] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [2024-10-10 00:21:51,806] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Generating embeddings: 100%|██████████| 5/5 [00:02<00:00,  2.24it/s]

# %%
query_engine = index.as_query_engine(include_text=True)

response = query_engine.query("What happened at Ryanair?")

print(str(response))
# Out:
# [2024-10-10 00:22:09,425] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [2024-10-10 00:22:11,176] [INFO] [httpx._send_single_request:1786] [PID:809] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-10-10 00:22:14,214] [INFO] [httpx._send_single_request:1038] [PID:809] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Ryanair sacked its chief pilot after an investigation into alleged sexual harassment of female colleagues. The chief pilot, Aidan Murray, was terminated for a pattern of inappropriate behavior towards several female pilots. The airline's chief people officer, Darrell Hughes, confirmed the termination and emphasized the importance of a safe work environment. The dismissal followed complaints from junior colleagues about harassment and inappropriate conduct by Mr. Murray.
